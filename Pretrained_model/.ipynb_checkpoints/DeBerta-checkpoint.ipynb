# %%
# !pip install transformers datasets scikit-learn
# !pip ininstall transformers
# !pip install transformers==4.51.3
from transformers import TrainingArguments

from sklearn.model_selection import train_test_split
# Out:
# ...
# ERROR: unknown command "ininstall" - maybe you meant "uninstall"
# ...

# %%
from datasets import load_dataset
import pandas as pd

url = "https://drive.google.com/file/d/128ZRqLJrmRgm8fl1yEzWUm8vDUOTaQZk/view?usp=sharing" #
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
df = pd.read_csv(path)

# %%
# !pip install gdown

# %%
import gdown

url = 'https://drive.google.com/uc?id=128ZRqLJrmRgm8fl1yEzWUm8vDUOTaQZk'
output = 'train.csv'
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=128ZRqLJrmRgm8fl1yEzWUm8vDUOTaQZk
# To: /content/train.csv
# 100%|██████████| 31.5M/31.5M [00:00<00:00, 82.9MB/s]
# 'train.csv'

# %%
import pandas as pd

df = pd.read_csv('train.csv')
df.head()
# Out:
#    Unnamed: 0                                          statement   status
# 0           0                                         oh my gosh  Anxiety
# 1           1  trouble sleeping, confused mind, restless hear...  Anxiety
# 2           2  All wrong, back off dear, forward doubt. Stay ...  Anxiety
# 3           3  I've shifted my focus to something else but I'...  Anxiety
# 4           4  I'm restless and restless, it's been a month n...  Anxiety

# %%
import pandas as pd

# Load your CSV first into DataFrame to check for issues
df = pd.read_csv("train.csv")

# Drop nulls
df = df.dropna(subset=["statement", "status"])

# Strip leading/trailing spaces
df["statement"] = df["statement"].str.strip()
df["status"] = df["status"].str.strip()

# Optional: Remove empty strings
df = df[df["statement"] != ""]

# Save cleaned version
df.to_csv("train_clean.csv", index=False)

# %%
# !ls /content
# Out:
# mental_health_clean.csv  test.csv	  train.csv
# sample_data		 train_clean.csv  validation.csv

# %%
# Cleaning the data
df = df.dropna(subset=["statement", "status"])

df = df.drop_duplicates(subset=["statement"])

df = df[df["statement"].str.strip() != ""]

df = df.reset_index(drop=True)

# Save
df.to_csv("mental_health_clean.csv", index=False)

# final counts
print(df["status"].value_counts())
# Out:
# status
# Normal                  16039
# Depression              15087
# Suicidal                10641
# Anxiety                  3617
# Bipolar                  2501
# Stress                   2293
# Personality disorder      895
# Name: count, dtype: int64

# %%
# Spliting into train, validation, test (80/10/10)
train_df, temp_df = train_test_split(df, test_size=0.2, random_state=42, stratify=df["status"])
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42, stratify=temp_df["status"])

# %%
# Saving split datasets
train_df.to_csv("train.csv", index=False)
val_df.to_csv("validation.csv", index=False)
test_df.to_csv("test.csv", index=False)

# %%
from datasets import load_dataset

dataset = load_dataset("csv", data_files={
    "train": "train.csv",
    "validation": "validation.csv",
    "test": "test.csv"
})
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
# Get unique status labels
statuses = dataset["train"].unique("status")
statuses.sort()

# Create mappings
status2id = {status: i for i, status in enumerate(statuses)}
id2status = {i: status for status, i in status2id.items()}

# Map status to labels column
def encode_status(example):
    example["labels"] = status2id[example["status"]]
    return example

dataset = dataset.map(encode_status)
# Out:
# ...
# Map:   0%|          | 0/5108 [00:00<?, ? examples/s]

# %%
 from transformers import AutoTokenizer

model_name = "microsoft/deberta-v3-base"
tokenizer = AutoTokenizer.from_pretrained(model_name)

def tokenize_function(example):
    encoding = tokenizer(example["statement"], truncation=True, padding="max_length", max_length=128)
    encoding["status"] = example["status"]
    return encoding

tokenized_datasets = dataset.map(tokenize_function, batched=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/convert_slow_tokenizer.py:559: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# ...
# Map:   0%|          | 0/5108 [00:00<?, ? examples/s]

# %%
pip install transformers --upgrade

# %%
from transformers import TrainingArguments, Trainer, AutoModelForSequenceClassification
import numpy as np
from sklearn.metrics import accuracy_score, classification_report

# Load model
model = AutoModelForSequenceClassification.from_pretrained(
    model_name,
    num_labels=len(status2id)
)

# TrainingArguments
# Remove 'evaluation_strategy' and use 'eval_steps' to define evaluation frequency.
training_args = TrainingArguments(
    output_dir="./results",
    num_train_epochs=3,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    # Evaluate every 'eval_steps' steps during training
    eval_steps=100,
    save_strategy="epoch",
    load_best_model_at_end=False,
    metric_for_best_model="accuracy",
    logging_dir="./logs",
    logging_steps=10,
    seed=42,
    report_to="none"
)

# Metrics function
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    acc = accuracy_score(labels, predictions)
    return {"accuracy": acc}

# Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    compute_metrics=compute_metrics
)
# Out:
# Some weights of DebertaV2ForSequenceClassification were not initialized from the model checkpoint at microsoft/deberta-v3-base and are newly initialized: ['classifier.bias', 'classifier.weight', 'pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='7662' max='7662' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7662/7662 59:38, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>1.812200</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.445700</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.311500</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.306700</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.150900</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.986800</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.027000</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.058800</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.995700</td>
#     </tr>
#     <tr>
# ...

# %%
predictions = trainer.predict(tokenized_datasets["test"])
pred_labels = np.argmax(predictions.predictions, axis=-1)

# Print classification report
print(classification_report(tokenized_datasets["test"]["labels"], pred_labels, target_names=statuses))
# Out:
#                       precision    recall  f1-score   support
#
#              Anxiety       0.87      0.90      0.88       362
#              Bipolar       0.88      0.80      0.84       250
#           Depression       0.78      0.77      0.77      1509
#               Normal       0.97      0.96      0.96      1604
# Personality disorder       0.71      0.64      0.67        89
#               Stress       0.73      0.77      0.75       230
#             Suicidal       0.70      0.74      0.72      1064
#
#             accuracy                           0.83      5108
#            macro avg       0.81      0.80      0.80      5108
#         weighted avg       0.83      0.83      0.83      5108

# %%
model_dir = "./mental_health_deberta_v1"
model.save_pretrained(model_dir)
tokenizer.save_pretrained(model_dir)
# Out:
# ('./mental_health_deberta_v1/tokenizer_config.json',
#  './mental_health_deberta_v1/special_tokens_map.json',
#  './mental_health_deberta_v1/spm.model',
#  './mental_health_deberta_v1/added_tokens.json',
#  './mental_health_deberta_v1/tokenizer.json')

# %%
from google.colab import drive
drive.mount('/content/drive')

# Save model and tokenizer to your Drive
model.save_pretrained("/content/drive/MyDrive/mental_health_deberta_v1")
tokenizer.save_pretrained("/content/drive/MyDrive/mental_health_deberta_v1")
# Out:
# Mounted at /content/drive
# ('/content/drive/MyDrive/mental_health_deberta_v1/tokenizer_config.json',
#  '/content/drive/MyDrive/mental_health_deberta_v1/special_tokens_map.json',
#  '/content/drive/MyDrive/mental_health_deberta_v1/spm.model',
#  '/content/drive/MyDrive/mental_health_deberta_v1/added_tokens.json',
#  '/content/drive/MyDrive/mental_health_deberta_v1/tokenizer.json')

# %%
model.save_pretrained("/content/drive/MyDrive/mental_health_deberta_v1")

# %%
decoded_preds = [id2status[p] for p in pred_labels]
print(decoded_preds[:10])  # First 10 predictions
# Out:
# ['Depression', 'Stress', 'Suicidal', 'Anxiety', 'Depression', 'Normal', 'Normal', 'Normal', 'Normal', 'Anxiety']
